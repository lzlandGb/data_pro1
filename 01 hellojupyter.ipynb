# %%
print('hello')
# Out:
# hello

# %%
# %run 02j_print.py

# %%
test()
# Out:
# hello jupyter 这里是外部函数

# %%
# %time test()
# Out:
# hello jupyter 这里是外部函数
# CPU times: user 34 µs, sys: 2 µs, total: 36 µs
# Wall time: 40.3 µs

# %%
# %%timeit
test()
print('hello')
test()
# Out:
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# hello jupyter 这里是外部函数
# hello jupyter 这里是外部函数
# hello
# ...

# %%
print("hhh")
# Out:
# hhh

# %%
def fibo(count):
    a = 1
    b = 1
    for i in range(count):
        print(a)
        a = a + b
        b = a + b

# %%
fibo(10)
# Out:
# 1
# 2
# 5
# 13
# 34
# 89
# 233
# 610
# 1597
# 4181
